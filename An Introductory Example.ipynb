# %% [markdown]
# # 3. An Introductory Example

# %% [markdown]
# ## Examples

# %% [markdown]
# ### Plottings

# %%
2+1
# Out:
# 3

# %%
import numpy as np
import matplotlib.pyplot as plt

ϵ_values = np.random.randn(100)
plt.plot(ϵ_values)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10,6)

# Fixing random state for reproducibility
np.random.seed(19680801)

# Compute pie slices
N = 20
θ = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = 10 * np.random.rand(N)
width = np.pi / 4 * np.random.rand(N)
colors = plt.cm.viridis(radii / 10.)

ax = plt.subplot(111, projection='polar')
ax.bar(θ, radii, width=width, bottom=0.0, color=colors, alpha=0.5)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

ε_values = np.random.randn(100)
print(ε_values)
plt.plot(ε_values)
plt.show()
# Out:
# [ 2.1072047   0.03668338 -0.6743842   0.85628598 -0.181813    0.1206426
#   1.24681724  1.29704833  0.48107736 -0.03770591 -1.26397183  1.73710982
#   1.7343424   1.86010606  1.11977623  1.40821099  0.24265609 -0.99292521
#   0.68705567  0.15847132 -1.19481931 -1.45296398  1.06904669  0.07941683
#  -0.10798785 -0.20849973 -0.87439282  1.08074644 -0.31075387  0.7428461
#   0.27592025  1.04932146  0.23505643  0.31453345  0.14121604  0.02261669
#   1.51129927 -0.46086916  0.21308877  1.44006756  0.09421234 -1.78572161
#  -0.33324507 -0.70547087 -1.36146291  1.15094639  0.03806828 -0.98792815
#  -0.86807516  0.97267875 -0.06065201  1.13876379  2.08647516  0.3941303
#  -0.36569198 -0.01345546  0.85221133  1.90507006 -0.57921103 -0.70427026
#   0.58575278 -0.48458103 -0.42361234 -1.12645119  0.72044854 -0.37907091
#  -0.06472686  1.07152509  1.18003706  0.36407371 -0.53660627  0.93821544
#  -0.95177349  1.87919679  0.1270308  -0.2632554  -0.68047407  0.62832054
#  -2.84011059 -0.42011195 -0.10031469  1.41257076 -0.74820661  0.38649925
#  -0.18521644  0.56968607  1.03434776 -0.17439486 -0.46750311 -0.69072596
#   0.34942923  1.43792041  1.05171949 -0.97143856 -1.6029639   0.95537142
#   0.67935304 -1.46593105 -1.01254057  0.61614448]

# %%
np.sqrt(4)
np.log(4)
# Out:
# 1.3862943611198906

# %%
print(np.__file__)
# Out:
# C:\ProgramData\anaconda3\envs\quantecon\lib\site-packages\numpy\__init__.py

# %%
ts_length = 100
ε_values = [] # empty list

for i in range(ts_length):
    e = np.random.randn()
    ε_values.append(e)

plt.plot(ε_values)
plt.show()

# %%
x = [10,'foo',False]
type(x)
# Out:
# list

# %%
x.append(2.5)
x
# Out:
# [2.5]

# %%
x.pop()
x
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 x.pop()
#       2 x
#
# IndexError: pop from empty list

# %%
x
# Out:
# []

# %% [markdown]
# ### For Loop

# %%
animals = ['dogs','cat','bird']
for animal in animals:
    print('The plural of ' + animal + ' is ' +animal +  's')
# Out:
# The plural of dogs is dogss
# The plural of cat is cats
# The plural of bird is birds

# %% [markdown]
# ### While Loop

# %%
ts_length = 100
ε_values = []
i=0
while i < ts_length:
    e = np.random.randn()
    ε_values.append(e)
    i = i+1

plt.plot(ε_values)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Another Application
# Let’s do one more application before we turn to exercises.
#
# In this application, we plot the balance of a bank account over time.
#
# There are no withdraws over the time period, the last date of which is denoted by $T$.
#
# The initial balance is $b_0$  and the interest rate is $r$.
#
# The balance updates from period $t$ to $t+1$  according to $b_{t+1} = (1 +r)b_t$.
#
# In the code below, we generate and plot the sequence $b_0,b_1,...,b_T$.
#
# Instead of using a Python list to store this sequence, we will use a NumPy array.

# %%
r = 0.025 # interest rate
T = 50 # end date
b = np.empty(T+1) # an empty Numpy array, to store all b_t
b[0] = 10

for t in range(T):
    b[t+1] = (1 +r)*b[t]

plt.plot(b, label='bank balance')
plt.legend()
plt.show()

# %% [markdown]
# ## Exercise

# %% [markdown]
# ### Exercise 3.1
#
# Your first task is to simulate and plot the correlated time series
#
# $ x_{t+1} = {\alpha}x_t + \epsilon_{t+1} $ where $ x_0$ and $t = 0,...,T $
#
# The sequence of shocks $\{ \epsilon_t \}$  is assumed to be IID and standard normal.
#
# In your solution, restrict your import statements to
# ```python
#     import numpy as np
#     import matplotlib.pyplot as plt
# ```
# Set $T = 200$ and $\alpha = 0.9$

# %%
import numpy as np
import matplotlib.pyplot as plt

T = 200
x = np.empty(T+1)
x[0] = 0
α = 0.9

for t in range(T):
    x[t+1] = α*x[t] + np.random.randn()
   

plt.plot(x)
plt.show()

# %% [markdown]
# ### Exercise 3.2
#
# Starting with your solution to exercise 1, plot three simulated time series, one for each of the cases $\alpha = 0$, $\alpha = 0.8$, and $\alpha = 0.98$.
#
# Use a \for loop to step through the $\alpha $ values.
#
# If you can, add a legend, to help distinguish between the three time series.

# %%
α_values =[0,0.8, 0.98]

T = 200
x = np.empty(T+1)

for α in α_values:
    x[0] = 0
    for t in range(T):
        x[t+1] = α*x[t] + np.random.randn()
    plt.plot(x, label=f'$\\alpha = {α}$')

plt.legend()
plt.show()
